# %% [markdown]
# Search Method: find()

# %%
print("Jai Ganesh")
# Out:
# Jai Ganesh

# %%
text = "Hello, welcome to python programming! python"

# %%
print(text)
# Out:
# Hello, welcome to python programming! python

# %%
index=text.find("python")

# %%
print(index)
# Out:
# 18

# %%
index=text.find("python1")

# %%
print(index)
# Out:
# -1

# %%
print(len(text))
# Out:
# 44

# %%
str1="hello"

# %%
print(len(str1))
# Out:
# 5

# %%
print(str1.find("o"))
# Out:
# 4

# %% [markdown]
# Replace Method: replace()

# %%
text = "Hello, welcome to Python programming"

# %%
new_text=text.replace("Python","Java")

# %%
print(new_text)
# Out:
# Hello, welcome to Java programming

# %% [markdown]
# Trim Whitespace Methods

# %% [markdown]
# lstrip()

# %%
text = "   Hello, world   "

# %%
print(text)
# Out:
#    Hello, world

# %%
result=text.lstrip()

# %%
print(result)
# Out:
# Hello, world

# %% [markdown]
# rstrip()

# %%
text = "   Hello, world   "

# %%
print(text)
# Out:
#    Hello, world

# %%
result1=text.rstrip()

# %%
print(result1)
# Out:
#    Hello, world

# %% [markdown]
# strip()

# %%
text = "   Hello, world   "

# %%
result3=text.strip()

# %%
print(result3)
# Out:
# Hello, world

# %% [markdown]
# Split Method: split()

# %%
str1 = "hello, welcome to india"

# %%
words=str1.split()

# %%
print(words)
# Out:
# ['hello,', 'welcome', 'to', 'india']

# %%
str2 = "hello, welcome to india"

# %%
words1=str2.split(",")

# %%
print(words1)
# Out:
# ['hello', ' welcome to india']

# %%
str3 = "apple, banana, cherry, mango"

# %%
words2=str3.split(",")

# %%
print(words2)
# Out:
# ['apple', ' banana', ' cherry', ' mango']

# %%
str4 = "apple@ banana$ cherry"

# %%
words3=str4.split("@")

# %%
print(words3)
# Out:
# ['apple', ' banana$ cherry']

# %% [markdown]
# Partition Method: partition()

# %%
str1 = "Who are you?"

# %%
result=str1.partition("are")

# %%
print(result)
# Out:
# ('Who ', 'are', ' you?')

# %%
str2 = "hello, welcome to india"

# %%
result1=str2.partition("to")

# %%
print(result1)
# Out:
# ('hello, welcome ', 'to', ' india')

# %% [markdown]
# Case Conversion Methods

# %% [markdown]
# lower()

# %%
str1="jai GANESH"

# %%
result=str1.lower()

# %%
print(result)
# Out:
# jai ganesh

# %% [markdown]
# upper()

# %%
str2="jai ganesh"

# %%
result2=str2.upper()

# %%
print(result2)
# Out:
# JAI GANESH

# %%
str2="JAI ganesh"

# %%
result2=str2.upper()

# %%
print(result2)
# Out:
# JAI GANESH

# %% [markdown]
# capitalize()

# %%
str3="jAI GANESH"

# %%
result3=str3.capitalize()

# %%
print(result3)
# Out:
# Jai ganesh

# %% [markdown]
# title()

# %%
str4="jai ganesh jai shree RAM"

# %%
result4=str4.title()

# %%
print(result4)
# Out:
# Jai Ganesh Jai Shree Ram

# %% [markdown]
# swapcase()

# %%
str5="JaI gAnEsH"

# %%
result5=str5.swapcase()

# %%
print(result5)
# Out:
# jAi GaNeSh

# %% [markdown]
# Type Conversion: str()

# %%
a=10
b=10.1
c=1+2j
d=True
e="hello"

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
f=str(a)

# %%
print(type(f))
# Out:
# <class 'str'>

# %%
g=str(b)

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
print(type(g))
# Out:
# <class 'str'>

# %%
print(type(c))
# Out:
# <class 'complex'>

# %%
h=str(c)

# %%
print(type(h))
# Out:
# <class 'str'>

# %%
i=True

# %%
print(type(i))
# Out:
# <class 'bool'>

# %%
j=str(i)

# %%
print(type(j))
# Out:
# <class 'str'>

# %% [markdown]
# Type Conversion: int()

# %%
a=10
b=10.1
c=1+2j
d=True
e="hello"

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
g=int(b)

# %%
print(g)
# Out:
# 10

# %%
print(type(g))
# Out:
# <class 'int'>

# %%
print(type(c))
# Out:
# <class 'complex'>

# %%
print(type(e))
# Out:
# <class 'str'>

# %%
e="10"

# %%
print(type(e))
# Out:
# <class 'str'>

# %%
j=int(e)

# %%
print(type(j))
# Out:
# <class 'int'>

# %%
print(j)
# Out:
# 10

# %%
a=10

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
k=float(a)

# %%
print(k)
# Out:
# 10.0

# %%
print(type(k))
# Out:
# <class 'float'>

# %% [markdown]
# Function_Use

# %%
# Ex.len(),min(),max()

# %%
#fun_name(str_name)

# %% [markdown]
# Method_use

# %%
#str_name.method_name()

# %% [markdown]
# ord()

# %%
unicode=ord("@")

# %%
print(unicode)
# Out:
# 64

# %% [markdown]
# chr()

# %%
character=chr(122)

# %%
print(character)
# Out:
# z

# %% [markdown]
# join() Method

# %%
words = ['my', 'name', 'is', 'prashant']  # -> 'my name is prashant'

# %%
print(words)
# Out:
# ['my', 'name', 'is', 'prashant']

# %%
sentence=" ".join(words)

# %%
print(sentence)
# Out:
# my name is prashant
