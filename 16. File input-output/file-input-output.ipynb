# %% [markdown]
# ### File I/O — Opening, Writing & Reading

# %%
print("Jai Ganesh")
# Out:
# Jai Ganesh

# %% [markdown]
# ### Opening, Writing

# %%
quote1="I am learning File input-output"

# %%
quote1
# Out:
# 'I am learning File input-output'

# %%
len(quote1)
# Out:
# 31

# %%
obj1=open("text1.txt","w")

# %%
obj1.write(quote1)
# Out:
# 31

# %%
obj1.close()

# %% [markdown]
# ### Opening  & Reading

# %%
obj2=open("text1.txt","r")

# %%
result=obj2.read()

# %%
print(result)
# Out:
# I am learning File input-output

# %%
obj2.close()

# %%
obj3=open("text1.txt","w")

# %%
obj3.write("I have added new content")
# Out:
# 24

# %%
obj3.close()

# %%
obj4=open("text1.txt","r")

# %%
print(obj4.read())
# Out:
# I have added new content

# %%
result1=obj4.read()

# %%
result1
# Out:
# 'I have added new content'

# %% [markdown]
# ### Reading Data from Files

# %%
obj4=open("/home/prashant/Desktop/AI_Engineer_with_MLops_Course/16. File input-output/text1.txt","r")

# %%
result=obj4.read()

# %%
print(result)
# Out:
# I have added new content
# Name: Ganesh
# Roll No-100
# Address - Pune

# %%
obj5=open("/home/prashant/Desktop/AI_Engineer_with_MLops_Course/16. File input-output/text1.txt","r")

# %%
result1=obj5.read(50)

# %%
print(result1)
# Out:
# ed new content
# Name: Ganesh
# Roll No-100
# Address -

# %%
obj6=open("/home/prashant/Desktop/AI_Engineer_with_MLops_Course/16. File input-output/text1.txt","r")

# %%
result2=obj6.readlines()

# %%
print(result2[1:3])
# Out:
# ['Name: Ganesh\n', 'Roll No-100\n']

# %% [markdown]
# ### write(string)

# %%
obj7=open("text2.txt","w")

# %%
obj7.write(str(2+3j))
# Out:
# 6

# %%
obj7.close()

# %%
obj8=open("text2.txt","r")

# %%
result=obj8.read()

# %%
print(result)
# Out:
# (2+3j)

# %% [markdown]
# ### f.readline()

# %%
obj9=open("text3.txt","w")

# %%
paragraph=[
    "my name is ganesh\n",
    "my roll no is 100\n",
    "I live in pune\n"
]

# %%
obj9.writelines(paragraph)

# %%
obj9.close()

# %%
obj10=open("text3.txt","r")

# %%
result=obj10.read()

# %%
print(result)
# Out:
# my name is ganesh
# my roll no is 100
# I live in pune

# %%
obj11=open("text3.txt","r")

# %%
result=obj11.readlines()

# %%
print(result)
# Out:
# ['my name is ganesh\n', 'my roll no is 100\n', 'I live in pune\n']

# %%
obj12=open("text4.txt","w")

# %%
paragraph="""
    my name is ganesh
    my roll no is 100
    I live in pune
"""

# %%
obj12.write(paragraph)
# Out:
# 64

# %%
obj12.close()

# %%
obj13=open("text4.txt","r")

# %%
result=obj13.read()

# %%
print(result)
# Out:
#     my name is ganesh
#     my roll no is 100
#     I live in pune

# %%
obj14=open("text4.txt","a")

# %%
obj14.write("Ganesh works in IT company")
# Out:
# 26

# %%
obj14.close()

# %%
obj14=open("text4.txt","r")

# %%
result=obj14.read()

# %%
print(result)
# Out:
#     my name is ganesh
#     my roll no is 100
#     I live in pune
# Ganesh works in IT company

# %%
obj15=open("text4.txt","w+")

# %%
obj15.write("ganesh is python developer")
# Out:
# 26

# %%
obj15.close()

# %%
obj16=open("text4.txt","r")
result=obj16.read()
print(result)
# Out:
# ganesh is python developer

# %%
obj15 = open("text5.txt", "w+")

obj15.write("Hello Python\n")
obj15.write("Learning file handling")

obj15.seek(0)   # move cursor to beginning

data = obj15.read()
print(data)

obj15.close()
# Out:
# Hello Python
# Learning file handling
