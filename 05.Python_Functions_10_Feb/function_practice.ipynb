# %%
print("Jai Ganesh")
# Out:
# Jai Ganesh

# %%
length=int(input("Enter the length"))
width=int(input("Enter the width"))
area=length*width
print("Area is :",area)
# Out:
# Area is : 50

# %%
length=int(input("Enter the length"))
width=int(input("Enter the width"))
area=length*width
print("Area is :",area)
# Out:
# Area is : 50

# %%
string1="jai ganesh"

# %%
print(string1)
# Out:
# jai ganesh

# %%
len(string1)
# Out:
# 10

# %%
max(string1)
# Out:
# 's'

# %%
min(string1)
# Out:
# 'a'

# %%
def display_jai_ganesh():
    print("Jai Ganesh")

# %%
display_jai_ganesh()
# Out:
# Jai Ganesh

# %%
tuple1=(10,20,30)

# %%
print(sum(tuple1))
# Out:
# 60
