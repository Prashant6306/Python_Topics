# %%
print("Jai Ganesh")
# Out:
# Jai Ganesh

# %%
def summation(a,b):
    return a+b

result=summation(10,20)
print(result)
# Out:
# 30

# %%
class summation_class:
    def __init__(self,x,y):
        self.a=x
        self.b=y
    def addtiton(self):
        return (self.a+self.b)

obj5=summation_class(10,20)

# %%
obj5.addtiton()
# Out:
# 30

# %%
class Student:
    def __init__(self,name,roll_no):
        self.name=name
        self.roll_no=roll_no
        print("__init__ Maginc method called")
    def display(self):
        print("Name is:",self.name)
        print("Roll No. is:",self.roll_no)


obj1=Student("Ganesh",101)
obj3=Student("Rajesh",103)
# Out:
# __init__ Maginc method called
# __init__ Maginc method called

# %%
obj1.display()
# Out:
# Name is: Ganesh
# Roll No. is: 101

# %%
obj3.display()
# Out:
# Name is: Rajesh
# Roll No. is: 103

# %%
obj1.name
# Out:
# 'Ganesh'

# %%
obj1.roll_no
# Out:
# 101

# %%
obj3.name
# Out:
# 'Rajesh'

# %%
obj3.roll_no
# Out:
# 103

# %%
print(type(obj1))
# Out:
# <class '__main__.Student'>

# %%
print(id(obj1))
# Out:
# 134438858244880

# %%
obj1.display()
# Out:
# Name is: Ganesh
# Roll No. is: 101

# %%
print(obj1.name)
# Out:
# Ganesh

# %%
print(obj1.roll_no)
# Out:
# 101

# %%
print(id(obj2))
# Out:
# 134438858245456

# %%
obj2=Student("Ramesh",102)
# Out:
# __init__ Maginc method called

# %%
obj2.display()
# Out:
# Name is: Ramesh
# Roll No. is: 102

# %%
print(obj2.name)
# Out:
# Ramesh

# %%
print(obj2.roll_no)
# Out:
# 102

# %%
obj3.display()
# Out:
# Name is: Rajesh
# Roll No. is: 103

# %%
print(obj3.name)
# Out:
# Rajesh

# %%
print(obj3.roll_no)
# Out:
# 103

# %%
#obj_name=class_name()

# %%
str2=str("Hello")

# %%
print(type(str2))
# Out:
# <class 'str'>

# %%
str2.upper()
# Out:
# 'HELLO'

# %%
str2.swapcase()
# Out:
# 'hELLO'

# %%
str3=str("World")

# %%
str4=str2+str3

# %%
str4
# Out:
# 'HelloWorld'

# %%
print(str3)
# Out:
# World

# %%
print(str4)
# Out:
# HelloWorld

# %%
set1={1,2,3}
set2={5,6,7}

# %%
set3=set1+set2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 set3=set1+set2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
list1=[10,20,30]

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
len(list1)
# Out:
# 3

# %%
list1.append(40)

# %%
list1
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# ## User Defined Data Type in Python

# %%
3/4
# Out:
# 0.75

# %%
(3/4)*(1/4)
# Out:
# 0.1875

# %%
class Fraction:
    def __init__(self,x,y):
        self.numerator=x
        self.denominator=y
    def __str__(self):
        return "{}/{}".format(self.numerator,self.denominator)
    def __add__(self,other):
        new_num=(self.numerator *
                   other.denominator +
                   other.numerator *
                   self.denominator)
        new_den=(self.denominator *
                   other.denominator)
        return Fraction(new_num,new_den)
    def __sub__(self,other):
        new_num=(self.numerator *
                   other.denominator -
                   other.numerator *
                   self.denominator)
        new_den=(self.denominator *
                   other.denominator)
        return Fraction(new_num,new_den)
    def __mul__(self,other):
        new_num=self.numerator*other.numerator
        new_den=self.denominator*other.denominator
        return Fraction(new_num,new_den)
    def __truediv__(self,other):
        new_num=self.numerator*other.denominator
        new_den=self.denominator*other.numerator
        return Fraction(new_num,new_den)
    def convert_fraction_to_decimal(self):
        return (self.numerator/self.denominator)

# %%
fra1=Fraction(1,2)

# %%
print(fra1)
# Out:
# 1/2

# %%
fra2=Fraction(7,11)

# %%
print(fra2)
# Out:
# 7/11

# %%
print(fra1+fra2)
# Out:
# 25/22

# %%
print(fra1-fra2)
# Out:
# -3/22

# %%
print(fra1*fra2)
# Out:
# 7/22

# %%
print(fra1/fra2)
# Out:
# 11/14

# %%
print(fra1.convert_fraction_to_decimal())
# Out:
# 0.5

# %%
print(fra2.convert_fraction_to_decimal())
# Out:
# 0.6363636363636364
