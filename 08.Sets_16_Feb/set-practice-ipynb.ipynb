# %%
print("Jai Ganesh")
# Out:
# Jai Ganesh

# %%
set1={ 10,10.1,"ganesh",2+3j,True}

# %%
print(set1)
# Out:
# {True, 10.1, 'ganesh', 10, (2+3j)}

# %%
print(type(set1))
# Out:
# <class 'set'>

# %%
set2={ 10,10.1,"ganesh",2+3j,True,10}

# %% [markdown]
# # Unordered

# %%
print(set2)
# Out:
# {True, 10.1, 'ganesh', 10, (2+3j)}

# %%
set3=set()

# %%
print(set3)
# Out:
# set()

# %%
print(type(set3))
# Out:
# <class 'set'>

# %%
tuple1=tuple() # ()

# %%
print(tuple1)
# Out:
# ()

# %%
print(type(tuple1))
# Out:
# <class 'tuple'>

# %% [markdown]
# ****Accessing Set Elements****

# %%
set4={ 10,10.1,"ganesh",2+3j,True,10}

# %%
print(set4)
# Out:
# {True, 10.1, 'ganesh', 10, (2+3j)}

# %%
set1={10,20,30,40,50}

# %%
for i in set1:
    print(i)
# Out:
# 50
# 20
# 40
# 10
# 30

# %%
for index,value in enumerate(set1):
    print(index,value)
# Out:
# 0 50
# 1 20
# 2 40
# 3 10
# 4 30

# %% [markdown]
# Converting Other Types → Set

# %%
word="hello1"

# %%
char_set=set(word)

# %%
print(char_set)
# Out:
# {'o', '1', 'e', 'h', 'l'}

# %%
tuple1=(10,20,30)

# %%
set1=set(tuple1)

# %%
print(set1)
# Out:
# {10, 20, 30}

# %%
list1=[10,20,30]

# %%
set2=set(list1)

# %%
print(set2)
# Out:
# {10, 20, 30}

# %%
dict1={"name":"ganesh","roll_no":100}

# %%
set3=set(dict1)

# %%
print(set3)
# Out:
# {'name', 'roll_no'}

# %%
#my_range = 
range_to_set = set(range(1,6))
print(range_to_set)   # {0, 1, 2, 3, 4}
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# Aliasing

# %%
set1={10,20,30}

# %%
set2=set1

# %%
print(set1)
# Out:
# {10, 20, 30}

# %%
print(set1 is set2)
# Out:
# True

# %%
print(id(set1))
# Out:
# 133690001525440

# %%
print(id(set2))
# Out:
# 133690001525440

# %%
print(set2)
# Out:
# {10, 20, 30}

# %%
set1.add(40)

# %%
print(set1)
# Out:
# {40, 10, 20, 30}

# %%
print(set2)
# Out:
# {40, 10, 20, 30}

# %% [markdown]
# Cloning

# %%
set3={10,20,30}

# %%
set4=set3.copy()

# %%
print(set3 is set4)
# Out:
# False

# %%
print(id(set3))
# Out:
# 133690001538208

# %%
print(id(set4))
# Out:
# 133690001535296

# %%
print(set3)
# Out:
# {10, 20, 30}

# %%
print(set4)
# Out:
# {10, 20, 30}

# %%
set3.add(40)

# %%
print(set3)
# Out:
# {40, 10, 20, 30}

# %%
print(set4)
# Out:
# {10, 20, 30}

# %% [markdown]
# 'in' Membership Operator

# %%
set5={ 10,10.1,"ganesh",2+3j,True,10}

# %%
print("ganesh" in set5)
# Out:
# True

# %%
print("santosh" in set5)
# Out:
# False

# %% [markdown]
# Emptiness()

# %%
my_set = set()           # empty set

if not my_set:
    print("set is empty")
else:
    print("set is not empty")
# Out:
# set is empty

# %%
set1={10,20,30,40,50}

# %%
print(len(set1))
# Out:
# 5

# %%
print(sum(set1))
# Out:
# 150

# %%
print(max(set1))
# Out:
# 50

# %%
print(min(set1))
# Out:
# 10

# %%
print(all(set1))
# Out:
# True

# %%
print(any(set1))
# Out:
# True

# %%
print(sorted(set1))
# Out:
# [10, 20, 30, 40, 50]

# %%
set1.add(60)

# %%
set1
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
set2={70,80}

# %%
set1.update(set2)

# %%
set1
# Out:
# {10, 20, 30, 40, 50, 60, 70, 80}

# %%
data = {10, 20, 30, 40, 50}
data_copy = data.copy()
print(data_copy)   # {10, 20, 30, 40, 50}
# Out:
# {50, 20, 40, 10, 30}

# %%
data = {10, 20, 30, 40, 50}
data.remove(30)
#print(data)   # {10, 20, 40, 50}

# If element not found:
data.remove(99)  #/→ KeyError: 99
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_55/223577508.py in <cell line: 0>()
#       4
#       5 # If element not found:
# ----> 6 data.remove(99)  #/→ KeyError: 99
#
# KeyError: 99

# %%
data = {10, 20, 30, 40, 50}
#data.discard(30)
#print(data)   # {10, 20, 40, 50}

# If element not found:
data.discard(99)  #/→ KeyError: 99

# %%
data
# Out:
# {10, 20, 30, 40, 50}

# %%
data = {10, 20, 30, 40, 50}
data.clear()
print(data)   # set()   ← empty set
# Out:
# set()
