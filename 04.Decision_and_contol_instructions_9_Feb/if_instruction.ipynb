# %%
print("Jai ganesh")
# Out:
# Jai ganesh

# %% [markdown]
# if Instruction

# %%
age=17

# %%
print("statement1")
if (age>=18):
    print("you are eligible for voting")
    print("statement2")
    print("statement3")
    print("statement4")
    print("statement5")
print("statement6")
# Out:
# statement1
# statement6

# %% [markdown]
# else Instruction

# %%
age=16
print("statement7")
if (age>=18):
    print("you are  eligible for voting")
    print("statement8")
    print("statement9")
    print("statement10")
else:
    print("you are not eligible for voting")
    print("statement11")
print("statement12")
print("statement13")
# Out:
# statement7
# you are not eligible for voting
# statement11
# statement12
# statement13

# %% [markdown]
# if-elif-else instruction

# %%
percentage=float(input("Enter your percentage"))

# %%
if (percentage>=66):
    print("you scored distinsion")
elif (percentage>=60):
    print("you scored first class")
elif (percentage>=55):
    print("you scored second class")
elif (percentage>=40):
    print("you are pass")
else:
    print("you are failed")
print("program executed sucessfully")
# Out:
# you scored first class
# program executed sucessfully

# %% [markdown]
# and operator

# %%
age=int(input("Enter your age:"))
nationality=input("Enter your nationality")

# %%
print(age)
# Out:
# 20

# %%
print(nationality)
# Out:
# indian

# %%
print("statement1")
if ((age>=18) and (nationality=="indian")):
    print("you are eligible for voting")
    print("statement2")
    print("statement3")
    print("statement4")
    print("statement5")
print("statement6")
# Out:
# statement1
# you are eligible for voting
# statement2
# statement3
# statement4
# statement5
# statement6

# %% [markdown]
# or operator

# %%
age=int(input("Enter your age:"))
nationality=input("Enter your nationality")

# %%
print(age)
# Out:
# 10

# %%
print(nationality)
# Out:
# indian

# %%
print("statement1")
if ((age>=18) or (nationality=="indian")):
    print("you are eligible for voting")
    print("statement2")
    print("statement3")
    print("statement4")
    print("statement5")
print("statement6")
# Out:
# statement1
# you are eligible for voting
# statement2
# statement3
# statement4
# statement5
# statement6

# %% [markdown]
# not operator

# %%
age=int(input("Enter your age:"))

# %%
print(age)
# Out:
# 10

# %%
if not (age>=18):
    print("hi")
print("statement1")
# Out:
# hi
# statement1

# %% [markdown]
# Intendation

# %%
score=50
if (score>=60):
    print("Pass")
    print("Good")
print("Done")
# Out:
# Done

# %% [markdown]
# while loop

# %%
string1="HELLO"

# %%
print(len(string1))
# Out:
# 5

# %%
#built_in_function(string_variable)

# %%
string_variable.method_name()

# %%
string1.lower()
# Out:
# 'hello'

# %%
upper()
replace()
lstrip()
rstrip()
strip()
title()
swapcase()
partition()
isalpha()
join()

# %%
string1=["I","am","an","indian"]

# %%
string1="I am an indian"

# %%
print(string1.replace("indian","american"))
# Out:
# I am an american

# %%
string2=" ".join(string1)

# %%
print(string2)
# Out:
# I am an indian

# %%
# Out:
# range(0, 10)
