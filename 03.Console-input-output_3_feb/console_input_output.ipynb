# %% [markdown]
# input() Function

# %%
age=input()

# %%
print(age)
# Out:
# 10

# %%
print(type(age))
# Out:
# <class 'str'>

# %% [markdown]
# int without conversion

# %%
int1=input()

# %%
int2=input()

# %%
print(type(int1))
# Out:
# <class 'str'>

# %%
print(type(int2))
# Out:
# <class 'str'>

# %%
result=int1+int2

# %%
print(result)
# Out:
# 1020

# %% [markdown]
# Input Function Int type conversion

# %%
int1=input()

# %%
int2=input()

# %%
int1=int(int1)  # "10" -> 10

# %%
int2=int(int2)

# %%
result=int1+int2

# %%
print(result)
# Out:
# 30

# %% [markdown]
# Conversion on Single line

# %%
int1=int(input())

# %%
int2=int(input())

# %%
result=int1+int2

# %%
print(result)
# Out:
# 30

# %% [markdown]
# Passing Message to the user

# %%
int1=int(input("Enter First Number"))

# %%
int2=int(input("Enter Second Number"))

# %%
result=int1+int2

# %%
print("addition of int1 and int2 is :",result)
# Out:
# addition of int1 and int2 is : 30

# %% [markdown]
# Input() Examples

# %%
name=input("Enter your name")

# %%
age=int(input("Enter your age"))

# %%
print("My name is ",name,"and age is",age)   # My name is ganesh and age is 25
# Out:
# My name is  ganesh and age is 25

# %%
x=10;y=20
print("value of x is ",x, "and y is" ,y)
# value of x is x and y is y
# Out:
# value of x is  10 and y is 20

# %%
print("Welcome to india")
# Out:
# Welcome to india

# %%
print(10)
# Out:
# 10

# %%
print(10.1)
# Out:
# 10.1

# %%
print(2+3j)
# Out:
# (2+3j)

# %%
print(True)
# Out:
# True

# %%
age=int(input("Enter your age"))
weight=float(input("Enter your weight"))
name=str(input("Enter your name"))
complex1=complex(input("Enter the real and imaginary value"))

# %%
bool1=bool(input("Are you eligible for voting"))

# %%
print(bool1)
# Out:
# False

# %%
print(age,weight,name,complex1)
# Out:
# 10 15.5 ganesh (2+3j)

# %%
print(type(age))
print(type(weight))
print(type(name))
print(type(complex1))
print(type(bool1))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'complex'>
# <class 'bool'>

# %% [markdown]
# Print Simple Text

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Print() function with Variables

# %%
name="ganesh"
age=30
print("my name is", name ,"and age is" ,age)
print("my name is", name ,"and age is" ,age,sep="-")
# my name is ganesh and age is 25
# Out:
# my name is ganesh and age is 30
# my name is-ganesh-and age is-30

# %% [markdown]
# Print with Separator

# %%
print("mango","banana","coconut",sep="-")
# Out:
# mango-banana-coconut

# %%
print("statement1",end=" ")
print("statement2",end="->")
print("statement3")
# Out:
# statement1 statement2->statement3

# %% [markdown]
# Complete Example: Calculator

# %%
# Simple Calculator
print("=== Calculator ===")

# Get first number
#num1 = float(input("Enter first number: "))
num1 = input("Enter first number: ")
# Get second number
#num2 = float(input("Enter second number: "))
num2 = input("Enter second number: ")
# Calculate sum
total = num1 + num2

# Display result
print("Sum:", total)
# Out:
# === Calculator ===
# Sum: 10.520.5

# %%
print(type(num1))
# Out:
# <class 'str'>

# %%
print(type(total))
# Out:
# <class 'str'>

# %%
# Simple Calculator
print("=== Calculator ===")

# Get first number
num1 = float(input("Enter first number: "))

# Get second number
num2 = float(input("Enter second number: "))

# Calculate sum
total = num1 + num2

# Display result
print("Sum:", total)
#print("Sum: {}".format(total))
#print(f"Sum: {total}")
# Out:
# === Calculator ===
# Sum: 31.0

# %%
print(type(num1))
# Out:
# <class 'float'>

# %%
print(type(total))
# Out:
# <class 'float'>

# %% [markdown]
# Formatted Output

# %% [markdown]
# 1.comma method for pint()

# %%
name = "Alice"
age = 25

# %%
print("Name:",name,"Age:",age)
# Out:
# Name: Alice Age: 25

# %%
# Name: Alice Age:25

# %% [markdown]
# 2.String Concatenation

# %%
name = "Alice"
age = 25

# %%
print("Name:"+name+" "+"Age:"+str(age))
# Out:
# Name:Alice Age:25

# %% [markdown]
# 3.format() Method

# %%
name = "Bob"
age = 30
print("Name: {}, Age: {}".format(name,age))
#Name: Bob, Age: 30
# Out:
# Name: Bob, Age: 30

# %% [markdown]
# 4.f-strings (Recommended)

# %%
name = "Charlie"
age = 35
print(f"Name: {name}, Age: {age}")
#Name: Charlie, Age: 35
# Out:
# Name: Charlie, Age: 35

# %%
print("hello")
# Out:
# hello
